# %%
import kagglehub
import os
import cv2 as cv
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D, GlobalAveragePooling2D, Flatten
from tensorflow.keras.models import Sequential, Model
import matplotlib.pyplot as plt

# %%
path = kagglehub.dataset_download("harshwardhanfartale/eyes-defy-anemia")
print("Dataset downloaded to:", path)
# Out:
# Dataset downloaded to: /kaggle/input/eyes-defy-anemia

# %%
data = []

# %%
for root, dirs, files in os.walk(path):
    for file in files:
        if file.lower().endswith((".jpg", ".png", ".jpeg")):
            label = os.path.basename(root)  # folder name as label
            img_path = os.path.join(root, file)
            image = cv.imread(img_path)
            if image is not None:
                image = cv.resize(image, (64, 64))
                data.append([image, label])

# %%
images = np.array([item[0] for item in data]) / 255.0  # Normalize
labels = [item[1] for item in data]

# %%
encoder = LabelEncoder()
encoded = encoder.fit_transform(labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(images, encoded, test_size=0.2, random_state=42)

# %%
cnn_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPool2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPool2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(np.unique(encoded)), activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = cnn_model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.0082 - loss: 4.8350 - val_accuracy: 0.0217 - val_loss: 4.8120
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 262ms/step - accuracy: 0.0601 - loss: 4.7359 - val_accuracy: 0.0217 - val_loss: 4.8537
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.0658 - loss: 4.4653 - val_accuracy: 0.0072 - val_loss: 4.9352
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.1418 - loss: 3.9717 - val_accuracy: 0.0507 - val_loss: 5.2117
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.2660 - loss: 3.2605 - val_accuracy: 0.0580 - val_loss: 5.4680
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.4169 - loss: 2.3516 - val_accuracy: 0.0942 - val_loss: 5.9925
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 229ms/step - accuracy: 0.6552 - loss: 1.5129 - val_accuracy: 0.1232 - val_loss: 6.7855
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.8073 - loss: 0.7892 - val_accuracy: 0.1377 - val_loss: 7.8381
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.8772 - loss: 0.5403 - val_accuracy: 0.1449 - val_loss: 7.9691
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.9114 - loss: 0.3555 - val_accuracy: 0.1522 - val_loss: 8.3972
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.9589 - loss: 0.2298 - val_accuracy: 0.1522 - val_loss: 8.8986
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.9629 - loss: 0.1643 - val_accuracy: 0.1667 - val_loss: 8.9455
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.9851 - loss: 0.0950 - val_accuracy: 0.1667 - val_loss: 9.6022
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.9860 - loss: 0.0690 - val_accuracy: 0.1594 - val_loss: 9.7820
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.9966 - loss: 0.0338 - val_accuracy: 0.1594 - val_loss: 10.4502
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9953 - loss: 0.0266 - val_accuracy: 0.1667 - val_loss: 10.6934
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.9924 - loss: 0.0566 - val_accuracy: 0.1594 - val_loss: 10.1457
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.9983 - loss: 0.0318 - val_accuracy: 0.1594 - val_loss: 10.6175
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.9955 - loss: 0.0274 - val_accuracy: 0.1812 - val_loss: 10.4033
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - accuracy: 0.9932 - loss: 0.0189 - val_accuracy: 0.1812 - val_loss: 10.2641
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.9962 - loss: 0.0178 - val_accuracy: 0.1812 - val_loss: 10.5076
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.9988 - loss: 0.0073 - val_accuracy: 0.1812 - val_loss: 10.5190
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - accuracy: 0.9997 - loss: 0.0058 - val_accuracy: 0.1812 - val_loss: 10.7599
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 182ms/step - accuracy: 0.9979 - loss: 0.0145 - val_accuracy: 0.1884 - val_loss: 10.8508
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.1884 - val_loss: 11.1028
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.1884 - val_loss: 11.2629
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.1884 - val_loss: 11.4180
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1884 - val_loss: 11.5694
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.1884 - val_loss: 11.6862
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1884 - val_loss: 11.8063
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.1884 - val_loss: 11.8979
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.1884 - val_loss: 11.9868
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.1884 - val_loss: 12.0740
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.1884 - val_loss: 12.1543
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.1884 - val_loss: 12.2524
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 1.0000 - loss: 9.7253e-04 - val_accuracy: 0.1884 - val_loss: 12.3132
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 1.0000 - loss: 9.3188e-04 - val_accuracy: 0.1884 - val_loss: 12.3750
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.1884 - val_loss: 12.4459
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 1.0000 - loss: 9.3750e-04 - val_accuracy: 0.1884 - val_loss: 12.5077
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 1.0000 - loss: 8.4552e-04 - val_accuracy: 0.1884 - val_loss: 12.5839
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - accuracy: 1.0000 - loss: 7.8508e-04 - val_accuracy: 0.1884 - val_loss: 12.6243
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 1.0000 - loss: 6.8447e-04 - val_accuracy: 0.1884 - val_loss: 12.6768
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 1.0000 - loss: 7.0466e-04 - val_accuracy: 0.1884 - val_loss: 12.7380
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 258ms/step - accuracy: 1.0000 - loss: 7.7591e-04 - val_accuracy: 0.1884 - val_loss: 12.8116
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 1.0000 - loss: 7.0583e-04 - val_accuracy: 0.1884 - val_loss: 12.8568
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 1.0000 - loss: 6.5697e-04 - val_accuracy: 0.1884 - val_loss: 12.9026
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - accuracy: 1.0000 - loss: 6.0918e-04 - val_accuracy: 0.1884 - val_loss: 12.9525
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - accuracy: 1.0000 - loss: 6.0328e-04 - val_accuracy: 0.1884 - val_loss: 12.9971
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 1.0000 - loss: 5.2720e-04 - val_accuracy: 0.1884 - val_loss: 13.0375
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - accuracy: 1.0000 - loss: 5.0444e-04 - val_accuracy: 0.1812 - val_loss: 13.0905

# %%
cnn_model.save("anemia_cnn_model.h5")
print("CNN model saved as anemia_cnn_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# CNN model saved as anemia_cnn_model.h5
